# %% [markdown]
# Vamos a buscar los starbucks que hay en Berlín en un jupyter a parte para no ensuciar el principal

# %%
df_star

# %%
data = pd.read_csv("../input/directory.csv")

# %%
lista = [a for a in data["City"]]

# %%
print(set(lista))
# Out:
# {nan, '嘉兴市', 'Soul', 'Novi', 'Absecon', 'Rancho Cucamunga', 'North Reading', 'White Marsh', 'Aachen', 'Cheltenham', 'Gwangmyeong', 'Trussville', 'Marquette', 'Kent', 'Lucan', 'Hilversum', 'Campbell', 'Joint Base Andrews', 'Aliso Viejo', 'Pawleys Island', 'Patterson', 'Izmit', 'Broadlands', 'Pohang', 'Andorra la Vella', 'MAZATLAN', '昆山市', 'Gyeongju', 'Chikushino', 'Clifton Springs', 'Tyler', 'General Trias Cavite', 'Dickinson', 'Linden', 'MUENCHEN', 'Dorval', 'Sydney', 'Sharjah', 'Ft Wayne', 'Atwater', 'Hiroshima', '柳州', 'Anyang-si', 'Courbevoie', 'Kuwana', 'Cikampek', 'Missouri City', 'Genting Highland', 'Epping', 'Guaynabo', 'South Euclid', 'Clark', 'Gwangmyeong-si', 'West New York', 'Saint-Sauveur', 'Hornchurch', 'Wilmslow', 'Taplow', 'Hernando', 'Sano', 'TACOMA', 'Stanton', 'Lakeport', 'Chiswell Green', 'WILLCOX', 'Tulare', 'Puli Township', 'Port Richey', 'Cedar Falls', 'Kuki', 'Champaign', 'Hatsukaichi', 'Davao', 'Kearney', 'Vineland', 'Council Bluffs', 'Thousand Oaks', 'Sabah', 
# ...
